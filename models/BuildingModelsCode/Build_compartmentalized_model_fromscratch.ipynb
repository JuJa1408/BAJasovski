# %%
import cobra
from cobra import Model, Reaction, Metabolite
import numpy as np
import pandas as pd
import random
import seaborn as sns
import ecmtool
from os.path import join
from itertools import chain, permutations, product
# Out:
# pyparsing import
# CBGLPK based on swiglpk: not all methods implimented yet! 5.0
#
#
#
# No module named 'cplex'
#
#
#
# CPLEX not available
#
# *****
# Using GLPK
# *****
#
# doFBAMinSum not available with GLPK
#
#
# ***********************************************************************
# * Welcome to CBMPy (0.8.4) - PySCeS Constraint Based Modelling        *
# *                http://cbmpy.sourceforge.net                         *
# * Copyright(C) Brett G. Olivier 2014 - 2020                           *
# * Systems Biology Lab, Vrije Universiteit Amsterdam                   *
# * Amsterdam, The Netherlands                                          *
# * CBMPy is developed as part of the BeBasic MetaToolKit Project       *
# * Distributed under the GNU GPL v 3.0 licence, see                    *
# * LICENCE (supplied with this release) for details                    *
# ***********************************************************************
#
# ...

# %%
model = Model('comp_model_fromscratch')
# Out:
# Restricted license - for non-production use only - expires 2025-11-24

# %%
glc6p_srb = Metabolite('glc6p_srb', compartment='c')
CO2_srb = Metabolite('CO2_srb', compartment='c')
NADH_srb = Metabolite('NADH_srb', compartment='c')
rbl5p_srb = Metabolite('rbl5p_srb', compartment='c')
rbo5p_srb = Metabolite('rbo5p_srb', compartment='c')
xll5p_srb = Metabolite('xll5p_srb', compartment='c')
ery4p_srb = Metabolite('ery4p_srb', compartment='c')
fru6p_srb = Metabolite('fru6p_srb', compartment='c')
ga3p_srb = Metabolite('ga3p_srb', compartment='c')
ATP_srb = Metabolite('ATP_srb', compartment='c')
oaa_srb = Metabolite('oaa_srb', compartment='c')
PEP_srb = Metabolite('PEP_srb', compartment='c')
pyr_srb = Metabolite('pyr_srb', compartment='c')
ac_CoA_srb = Metabolite('ac_CoA_srb', compartment='c')
icit_srb = Metabolite('icit_srb', compartment='c')
akg_srb = Metabolite('akg_srb', compartment='c')
succ_srb = Metabolite('succ_srb', compartment='c')
SO4ex_gen = Metabolite('SO4ex_gen', compartment='e')
H2Sex_gen = Metabolite('H2Sex_gen', compartment='e')
glyox_srb = Metabolite('glyox_srb', compartment='c')
NADH_srb = Metabolite('NADH_srb', compartment='c')
H2_srb = Metabolite('H2_srb', compartment='c')
NH3_srb = Metabolite('NH3_srb', compartment='c')
ATPex_srb = Metabolite('ATPex_srb', compartment='c')
bm_srb = Metabolite('bm_srb', compartment='c')

CO2ex_gen = Metabolite('CO2ex_gen', compartment='e')
NH3ex_gen = Metabolite('NH3ex_gen', compartment='e')
H2pool_gen = Metabolite('H2pool_gen', compartment='s')

fru6p_fap = Metabolite('fru6p_fap', compartment='c')
ATP_fap = Metabolite('ATP_fap', compartment='c')
ga3p_fap = Metabolite('ga3p_fap', compartment='c')
glc6p_fap = Metabolite('glc6p_fap', compartment='c')
ery4p_fap = Metabolite('ery4p_fap', compartment='c')
CO2_fap = Metabolite('CO2_fap', compartment='c')
rbo5p_fap = Metabolite('rbo5p_fap', compartment='c')
rbl5p_fap = Metabolite('rbl5p_fap', compartment='c')
xll5p_fap = Metabolite('xll5p_fap', compartment='c')
ac_CoA_fap = Metabolite('ac_CoA_fap', compartment='c')
succ_fap = Metabolite('succ_fap', compartment='c')
mal_fap = Metabolite('mal_fap', compartment='c')
O2_fap = Metabolite('O2_fap', compartment='c')
glc6p_fap = Metabolite('glc6p_fap', compartment='c')
icit_fap = Metabolite('icit_fap', compartment='c')
oaa_fap = Metabolite('oaa_fap', compartment='c')
NADH_fap = Metabolite('NADH_fap', compartment='c')
NH3_fap = Metabolite('NH3_fap', compartment='c')
PEP_fap = Metabolite('PEP_fap', compartment='c')
pyr_fap = Metabolite('pyr_fap', compartment='c')
akg_fap = Metabolite('akg_fap', compartment='c')
PHB_fap = Metabolite('PHB_fap', compartment='c')
glyc_fap = Metabolite('glyc_fap', compartment='c')
glyox_fap = Metabolite('glyox_fap', compartment='c')
ATPex_fap = Metabolite('ATPex_fap', compartment='c')
CO2ex_gen = Metabolite('CO2ex_gen', compartment='e')
NH3ex_gen = Metabolite('NH3ex_gen', compartment='e')
H2_fap = Metabolite('H2_fap', compartment='c')
bm_fap = Metabolite('bm_fap', compartment='c')

H2pool_gen = Metabolite('H2pool_gen', compartment='e')

H2ex_gen = Metabolite('H2ex_gen', compartment='e')
hv_gen = Metabolite('hv_gen', compartment='e')
O2expool_gen = Metabolite('O2expool_gen', compartment='e')
ac_pool = Metabolite('ac_pool', compartment='e')
glycpool_gen = Metabolite('glycpool_gen', compartment='e')

ATP_syn = Metabolite('ATP_syn', compartment='c')
glc6p_syn = Metabolite('glc6p_syn', compartment='c')
polyglcex_gen = Metabolite('polyglcex_gen', compartment='e')
fru6p_syn = Metabolite('fru6p_syn', compartment='c')
glc6p_syn = Metabolite('glc6p_syn', compartment='c')
ga3p_syn = Metabolite('ga3p_syn', compartment='c')
NADH_syn = Metabolite('NADH_syn', compartment='c')
PEP_syn = Metabolite('PEP_syn', compartment='c')
pyr_syn = Metabolite('pyr_syn', compartment='c')
ac_CoA_syn = Metabolite('ac_CoA_syn', compartment='c')
CO2_syn = Metabolite('CO2_syn', compartment='c')
rbl5p_syn = Metabolite('rbl5p_syn', compartment='c')
xll5p_syn = Metabolite('xll5p_syn', compartment='c')
rbo5p_syn = Metabolite('rbo5p_syn', compartment='c')
ery4p_syn = Metabolite('ery4p_syn', compartment='c')
oaa_syn = Metabolite('oaa_syn', compartment='c')
icit_syn = Metabolite('icit_syn', compartment='c')
NH3_syn = Metabolite('NH3_syn', compartment='e')
O2_syn = Metabolite('O2_syn', compartment='c')
ATPex_syn = Metabolite('ATPex_syn', compartment='c')
akg_syn = Metabolite('akg_syn', compartment='c')
bm_syn = Metabolite('bm_syn', compartment='c')
glyc_syn = Metabolite('glyc_syn', compartment='c')
mal_syn = Metabolite('mal_syn', compartment='c')
succ_syn = Metabolite('succ_syn', compartment='c')
glyox_syn = Metabolite('glyox_syn', compartment='c')
O2ex_gen = Metabolite('O2ex_gen', compartment='e')

H2pool_gen_fap = Metabolite('H2pool_gen_fap', compartment='s')
glycpool_gen_fap = Metabolite('glycpool_gen_fap', compartment='s')
O2expool_gen_fap = Metabolite('O2expool_gen_fap', compartment='s')
ac_pool_fap = Metabolite('ac_pool_fap', compartment='s')
H2pool_gen_srb = Metabolite('H2pool_gen_srb', compartment='s')
ac_pool_srb = Metabolite('ac_pool_srb', compartment='s')
O2expool_gen_syn = Metabolite('O2expool_gen_syn', compartment='s')
glycpool_gen_syn = Metabolite('glycpool_gen_syn', compartment='s')
ac_pool_syn = Metabolite('ac_pool_syn', compartment='s')
N2ex_gen = Metabolite('N2ex_gen', compartment='e')

bm_fap_srb_syn = Metabolite('bm_fap_srb_syn', compartment='c')
bm = Metabolite('bm', compartment='c')

# %%
for i in range(1, 30):
    globals()[f'srb{i}'] = Reaction(f'srb{i}')
for i in range(1, 38):
    globals()[f'fap{i}'] = Reaction(f'fap{i}')
for i in range(1, 34):
    globals()[f'syn{i}'] = Reaction(f'syn{i}')
for i in range(1,12):
    globals()[f'pool{i}'] = Reaction(f'pool{i}')

    
bm_obj = Reaction('bm_obj')
bm1 = Reaction('bm1')
bm2 = Reaction('bm2')
bm3 = Reaction('bm3')

# %%
# Define reactions with their stoichiometries
srb1.add_metabolites({glc6p_srb: -1, CO2_srb: 1, NADH_srb: 2, rbl5p_srb: 1})
srb2.add_metabolites({rbl5p_srb: -1, rbo5p_srb: 1})
srb2.lower_bound = -1000
srb2.upper_bound = 1000
srb2.reversibility = True
 
srb3.add_metabolites({rbl5p_srb: -1, xll5p_srb: 1})
srb3.lower_bound = -1000
srb3.upper_bound = 1000
srb3.reversibility = True

srb4.add_metabolites({rbo5p_srb: -1, xll5p_srb: -1, ery4p_srb: 1, fru6p_srb: 1})
srb4.lower_bound = -1000
srb4.upper_bound = 1000
srb4.reversibility = True

srb5.add_metabolites({ery4p_srb: -1, xll5p_srb: -1, fru6p_srb: 1, ga3p_srb: 1})
srb5.lower_bound = -1000
srb5.upper_bound = 1000
srb5.reversibility = True

srb6.add_metabolites({ATP_srb: -1, oaa_srb: -1, CO2_srb: 1, PEP_srb: 1})
srb7.add_metabolites({ATP_srb: -1, NADH_srb: -1, PEP_srb: -1, ga3p_srb: 1})
srb7.lower_bound = -1000
srb7.upper_bound = 1000
srb7.reversibility = True

srb8.add_metabolites({ga3p_srb: -2, ATP_srb: 1, fru6p_srb: 1})
srb8.lower_bound = -1000
srb8.upper_bound = 1000
srb8.reversibility = True

srb9.add_metabolites({fru6p_srb: -1, glc6p_srb: 1})
srb9.lower_bound = -1000
srb9.upper_bound = 1000
srb9.reversibility = True

srb10.add_metabolites({ATP_srb: -1, CO2_srb: -1, pyr_srb: -1, oaa_srb: 1})
srb11.add_metabolites({ac_CoA_srb: -1, oaa_srb: -1, icit_srb: 1})
srb12.add_metabolites({icit_srb: -1, akg_srb: 1, CO2_srb: 1, NADH_srb: 1})
srb13.add_metabolites({akg_srb: -1, ATP_srb: 1, CO2_srb: 1, NADH_srb: 1, succ_srb: 1})
srb13.lower_bound = -1000
srb13.upper_bound = 1000
srb13.reversibility = True

srb14.add_metabolites({SO4ex_gen: -1, succ_srb: -2, ATP_srb: 0.25, H2Sex_gen: 1, oaa_srb: 2})
srb15.add_metabolites({icit_srb: -1, glyox_srb: 1, succ_srb: 1})
srb16.add_metabolites({ac_CoA_srb: -1, glyox_srb: -1, NADH_srb: 1, oaa_srb: 1})
srb17.add_metabolites({ATP_srb: -1, CO2_srb: -2, NADH_srb: -4, ac_CoA_srb: 1})
srb18.add_metabolites({ac_CoA_srb: -1, CO2_srb: -1, NADH_srb: -1, pyr_srb: 1})
srb18.lower_bound = -1000
srb18.upper_bound = 1000
srb18.reversibility = True

srb19.add_metabolites({H2_srb: -1, NADH_srb: 1})
srb20.add_metabolites({NADH_srb: -4, SO4ex_gen: -1, ATP_srb: 0.75, H2Sex_gen: 1})
srb21.add_metabolites({ATP_srb: -1, ATPex_srb: 1})
srb22.add_metabolites({ac_CoA_srb: -1.233, akg_srb: -1.472, ATP_srb: -50, ery4p_srb: -0.531, glc6p_srb: -0.069, NADH_srb: -14.653, NH3_srb: -12.513, oaa_srb: -2.379, PEP_srb: -2.67, pyr_srb: -4.057, rbo5p_srb: -0.787, bm_srb: 1})
srb23.add_metabolites({CO2ex_gen: -1, CO2_srb: 1})
srb23.lower_bound = -1000
srb23.upper_bound = 1000
srb23.reversibility = True

srb24.add_metabolites({NH3ex_gen: -1, NH3_srb: 1})
srb25.add_metabolites({H2pool_gen: -1, H2_srb: 1})
srb25.lower_bound = -1000
srb25.upper_bound = 1000
srb25.reversibility = True

srb26.add_metabolites({ATP_srb: -1, NADH_srb: -4, H2_srb: 4})
srb27.add_metabolites({ATP_srb: -2, pyr_srb: -1, PEP_srb: 1})
srb28.add_metabolites({PEP_srb: -1, ATP_srb: 1, pyr_srb: 1})
srb29.add_metabolites({ATP_srb: -1, ac_pool_srb: -1, ac_CoA_srb: 1})
fap1.add_metabolites({fru6p_fap: -1, glc6p_fap: 1})
fap2.add_metabolites({ATP_fap: -1, fru6p_fap: -1, ga3p_fap: 2})
fap2.lower_bound = -1000
fap2.upper_bound = 1000
fap2.reversibility = True

fap3.add_metabolites({ATP_fap: -1, NADH_fap: -1, PEP_fap: -1, ga3p_fap: 1})
fap4.add_metabolites({ATP_fap: -2, pyr_fap: -1, PEP_fap: 1})
fap5.add_metabolites({glc6p_fap: -1, CO2_fap: 1, NADH_fap: 2, rbl5p_fap: 1})
fap6.add_metabolites({rbl5p_fap: -1, xll5p_fap: 1})
fap6.lower_bound = -1000
fap6.upper_bound = 1000
fap6.reversibility = True

fap7.add_metabolites({rbl5p_fap: -1, rbo5p_fap: 1})
fap7.lower_bound = -1000
fap7.upper_bound = 1000
fap7.reversibility = True

fap8.add_metabolites({rbo5p_fap: -1, xll5p_fap: -1, ery4p_fap: 1, fru6p_fap: 1})
fap8.lower_bound = -1000
fap8.upper_bound = 1000
fap8.reversibility = True

fap9.add_metabolites({ery4p_fap: -1, xll5p_fap: -1, fru6p_fap: 1, ga3p_fap: 1})
fap9.lower_bound = -1000
fap9.upper_bound = 1000
fap9.reversibility = True

fap10.add_metabolites({ac_CoA_fap: -1, oaa_fap: -1, icit_fap: 1})
fap11.add_metabolites({icit_fap: -1, akg_fap: 1, CO2_fap: 1, NADH_fap: 1})
fap11.lower_bound = -1000
fap11.upper_bound = 1000
fap11.reversibility = True

fap12.add_metabolites({akg_fap: -1, ATP_fap: 1, CO2_fap: 1, NADH_fap: 1, succ_fap: 1})
fap13.add_metabolites({succ_fap: -1, O2_fap: -0.5, ATP_fap: 1.25, mal_fap: 1})
fap14.add_metabolites({mal_fap: -1, NADH_fap: 1, oaa_fap: 1})
fap14.lower_bound = -1000
fap14.upper_bound = 1000
fap14.reversibility = True

fap15.add_metabolites({icit_fap: -1, glyox_fap: 1, succ_fap: 1})
fap16.add_metabolites({ac_CoA_fap: -1, glyox_fap: -1, mal_fap: 1})
fap16.lower_bound = -1000
fap16.upper_bound = 1000
fap16.reversibility = True

fap17.add_metabolites({mal_fap: -1, CO2_fap: 1, NADH_fap: 1, pyr_fap: 1})
fap18.add_metabolites({ATP_fap: -1, oaa_fap: -1, CO2_fap: 1, PEP_fap: 1})
fap19.add_metabolites({ATP_fap: -1, glyox_fap: -2, NADH_fap: -1, CO2_fap: 1, PEP_fap: 1})
fap20.add_metabolites({ATP_fap: -1, ATPex_fap: 1})
fap21.add_metabolites({CO2_fap: -1, CO2ex_gen: 1})
fap21.lower_bound = -1000
fap21.upper_bound = 1000
fap21.reversibility = True

fap22.add_metabolites({H2pool_gen: -1, H2_fap: 1})
fap22.lower_bound = -1000
fap22.upper_bound = 1000
fap22.reversibility = True

fap23.add_metabolites({H2_fap: -1, NADH_fap: 1})
fap24.add_metabolites({NH3ex_gen: -1, NH3_fap: 1})
fap25.add_metabolites({ac_CoA_fap: -1.233, akg_fap: -1.472, ATP_fap: -50, ery4p_fap: -0.531, glc6p_fap: -0.069, NADH_fap: -14.653, NH3_fap: -12.513, oaa_fap: -2.379, PEP_fap: -2.67, pyr_fap: -4.057, rbo5p_fap: -0.787, bm_fap: 1})
fap26.add_metabolites({hv_gen: -2, ATP_fap: 1})
fap27.add_metabolites({NADH_fap: -2, O2_fap: -1, ATP_fap: 5})
fap28.add_metabolites({glyc_fap: -1, glyox_fap: 1, NADH_fap: 1})
fap29.add_metabolites({CO2_fap: -1, PEP_fap: -1, oaa_fap: 1})
fap30.add_metabolites({pyr_fap: -1, ac_CoA_fap: 1, CO2_fap: 1, NADH_fap: 1})
fap31.add_metabolites({ATP_fap: -4, CO2_fap: -1, glyox_fap: -1, NADH_fap: -3, pyr_fap: 1})
fap32.add_metabolites({ATP_fap: -1, NADH_fap: -4, H2_fap: 4})
fap33.add_metabolites({PEP_fap: -1, ATP_fap: 1, pyr_fap: 1})
fap34.add_metabolites({glycpool_gen: -1, glyc_fap: 1})
fap35.add_metabolites({O2expool_gen: -1, O2_fap: 1})
fap36.add_metabolites({ac_CoA_fap: -2, NADH_fap: -1, PHB_fap: 1})
fap37.add_metabolites({ATP_fap: -2, ac_pool_fap: -1, ac_CoA_fap: 1})
syn1.add_metabolites({ATP_syn: -1, glc6p_syn: -1, polyglcex_gen: 1})
syn2.add_metabolites({fru6p_syn: -1, glc6p_syn: 1})
syn3.add_metabolites({ga3p_syn: -2,  fru6p_syn: 1})
syn4.add_metabolites({ga3p_syn: -1, ATP_syn: 1, NADH_syn: 1, PEP_syn: 1})
syn4.lower_bound = -1000
syn4.upper_bound = 1000
syn4.reversibility = True

syn5.add_metabolites({ATP_syn: -2, pyr_syn: -1, PEP_syn: 1})
syn6.add_metabolites({pyr_syn: -1, ac_CoA_syn: 1, CO2_syn: 1, NADH_syn: 1})
syn7.add_metabolites({glc6p_syn: -1, CO2_syn: 1, NADH_syn: 2, rbl5p_syn: 1})
syn8.add_metabolites({rbl5p_syn: -1,  xll5p_syn: 1})
syn8.lower_bound = -1000
syn8.upper_bound = 1000
syn8.reversibility = True

syn9.add_metabolites({rbl5p_syn: -1,  rbo5p_syn: 1})
syn9.lower_bound = -1000
syn9.upper_bound = 1000
syn9.reversibility = True

syn10.add_metabolites({rbo5p_syn: -1, xll5p_syn: -1, ery4p_syn: 1, fru6p_syn: 1})
syn10.lower_bound = -1000
syn10.upper_bound = 1000
syn10.reversibility = True

syn11.add_metabolites({ery4p_syn: -1, xll5p_syn: -1,  fru6p_syn: 1, ga3p_syn: 1})
syn11.lower_bound = -1000
syn11.upper_bound = 1000
syn11.reversibility = True

syn12.add_metabolites({ac_CoA_syn: -1, oaa_syn: -1,  icit_syn: 1})
syn13.add_metabolites({CO2_syn: -1, CO2ex_gen: 1})
syn13.lower_bound = -1000
syn13.upper_bound = 1000
syn13.reversibility = True

syn14.add_metabolites({NH3_syn: -1,  NH3ex_gen: 1})
syn15.add_metabolites({ATP_syn: -1,  ATPex_syn: 1})
syn16.add_metabolites({ac_CoA_syn: -1.233, akg_syn: -1.472, ATP_syn: -50, ery4p_syn: -0.531, glc6p_syn: -0.069, NADH_syn: -14.653, NH3_syn: -12.513, oaa_syn: -2.379, PEP_syn: -2.67, pyr_syn: -4.057, rbo5p_syn: -0.787, bm_syn: 1})
syn17.add_metabolites({hv_gen: -8, ATP_syn: 3, NADH_syn: 2, O2_syn: 1})
syn18.add_metabolites({NADH_syn: -2, O2_syn: -1, ATP_syn: 5})
syn19.add_metabolites({CO2_syn: -1, PEP_syn: -1, oaa_syn: 1})
syn20.add_metabolites({O2_syn: -1, O2expool_gen: 1})
syn21.add_metabolites({ATP_syn: -1, rbl5p_syn: -1, O2_syn: -1, PEP_syn: 1, glyc_syn: 1})
syn22.add_metabolites({glyc_syn: -1, glycpool_gen: 1})
syn23.add_metabolites({PEP_syn: -1, ATP_syn: 1, pyr_syn: 1})
syn24.add_metabolites({ATP_syn: -1, CO2_syn: -1, rbl5p_syn: -1, PEP_syn: 2})
syn25.add_metabolites({ATP_syn: -1, fru6p_syn: -1, ga3p_syn: 2})
syn26.add_metabolites({icit_syn: -1, akg_syn: 1, CO2_syn: 1, NADH_syn: 1})
syn27.add_metabolites({mal_syn: -1, CO2_syn: 1, NADH_syn: 1, pyr_syn: 1})
syn28.add_metabolites({akg_syn: -1, ATP_syn: 1, CO2_syn: 1, NADH_syn: 1, succ_syn: 1})
syn29.add_metabolites({icit_syn: -1, succ_syn: 1, glyox_syn: 1})
syn30.add_metabolites({ATP_syn: -1, oaa_syn: -1, CO2_syn: 1, PEP_syn: 1})
syn31.add_metabolites({ac_CoA_syn: -1, ATP_syn: 1, ac_pool_syn: 1})
syn32.add_metabolites({O2_syn: -1, succ_syn: -2, ATP_syn: 2.5, mal_syn: 2})
syn33.add_metabolites({hv_gen: -2, ATP_syn: 1})
pool1.add_metabolites({H2pool_gen: -1, H2ex_gen: 1})
pool2.add_metabolites({O2expool_gen: -1, O2ex_gen: 1})
pool3.add_metabolites({H2pool_gen_fap: -1, H2_fap: 1})
pool3.lower_bound = -1000
pool3.upper_bound = 1000
pool3.reversibility = True

pool4.add_metabolites({glycpool_gen_fap: -1, glyc_fap: 1}) 
pool5.add_metabolites({O2expool_gen_fap: -1, O2_fap: 1})
pool6.add_metabolites({H2pool_gen_srb: -1, H2_srb: 1})
pool6.lower_bound = -1000
pool6.upper_bound = 1000
pool6.reversibility = True

pool7.add_metabolites({O2_syn: -1, O2expool_gen_syn: 1})
pool8.add_metabolites({glyc_syn: -1, glycpool_gen_syn: 1})
pool9.add_metabolites({ac_pool: -1, ac_pool_srb: 1})
pool10.add_metabolites({ac_pool: -1, ac_pool_fap: 1})
pool11.add_metabolites({ac_pool_syn: -1, ac_pool: 1})

bm1.add_metabolites({bm_fap: -1, bm_fap_srb_syn: 1})
bm2.add_metabolites({bm_srb: -1, bm_fap_srb_syn: 1})
bm3.add_metabolites({bm_syn: -1, bm_fap_srb_syn: 1})
bm_obj.add_metabolites({bm_fap: -0.33, bm_srb: -0.33, bm_syn: -0.33, bm: 1})


reactions_srb = [globals()[f'srb{i}'] for i in range(1, 30)]
reactions_fap = [globals()[f'fap{i}'] for i in range(1, 38)]
reactions_syn = [globals()[f'syn{i}'] for i in range(1, 34)]
reactions_pool = [globals()[f'pool{i}'] for i in range(1, 12)]

model.add_reactions(reactions_srb)
model.add_reactions(reactions_fap)
model.add_reactions(reactions_syn)
model.add_reactions(reactions_pool)
model.add_reactions([bm_obj, bm1, bm2, bm3])
# Out:
# C:\Users\Jasovsju\anaconda3\Lib\site-packages\cobra\core\reaction.py:810: UserWarning: Setting reaction reversibility is ignored
#   warn("Setting reaction reversibility is ignored")

# %%
exchange_metabolites = [
    "CO2ex_gen", "H2Sex_gen", "SO4ex_gen",  "H2ex_gen", "H2pool_gen", "O2expool_gen", "glycpool_gen", "ac_pool" 
]
demand_metabolites = [
     "PHB_fap", "polyglcex_gen",  "glyox_syn", "ATPex_fap", "ATPex_srb", "ATPex_syn", "bm_fap_srb_syn", "bm"
]
sink_metabolites = [
    "NH3_syn", "hv_gen"  
]

# Austauschreaktionen für alle externen Metaboliten hinzufügen
for met_id in exchange_metabolites:
    model.add_boundary(model.metabolites.get_by_id(met_id), type="exchange")

for met_id in demand_metabolites:
    model.add_boundary(model.metabolites.get_by_id(met_id), type="demand")

for met_id in sink_metabolites:
    model.add_boundary(model.metabolites.get_by_id(met_id), type="sink")

# %%
objective_id = str(bm_obj.id)
bm_obj.objective_coefficient = 1
model.objective.lower_bound = 0
model.objective.upper_bound = 1000
model.objective.reversibility = False
model.objective = model.reactions.get_by_id(objective_id)

# %%
cobra.io.write_sbml_model(model, 'compartmentalized_model.xml')
